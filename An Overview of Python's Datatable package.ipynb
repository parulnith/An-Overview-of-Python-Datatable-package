# %% [markdown]
# The datatable is an open-source library for tabular data manipulation. It is a younger sibling of R data.table, and attempts to mimic its API and some of the core algorithms. The development of datatable is sponsored by H2O.ai.

# %% [markdown]
# ## Installation

# %%
# Mac OSX
# !pip install datatable


# Linux
# Python 3.5
# !pip install https://s3.amazonaws.com/h2o-release/datatable/stable/datatable-0.8.0/datatable-0.8.0-cp35-cp35m-linux_x86_64.whl

# Python 3.6
# !pip install https://s3.amazonaws.com/h2o-release/datatable/stable/datatable-0.8.0/datatable-0.8.0-cp36-cp36m-linux_x86_64.whl

# Python 3.7
# !pip install https://s3.amazonaws.com/h2o-release/datatable/stable/datata


# Windows
# Currently, datatable does not work on Windows.

# %% [markdown]
# ## Importing Necessary Libraries

# %%
import numpy as np
import pandas as pd
import datatable as dt

# %% [markdown]
# **Dataset**: https://www.kaggle.com/wendykan/lending-club-loan-data/downloads/loan.csv/1
#
# The dataset being used has been taken from Kaggle and belongs to the Lending Club Loan Data Dataset. The dataset consists of complete loan data for all loans issued through the 2007–2015, including the current loan status (Current, Late, Fully Paid, etc.) and latest payment information. The file consists of 2.26 Million and 145 columns. The data size is ideal to demonstrate the capabilities of the datatable library.

# %% [markdown]
# ## Reading Data with datatable
#
# The fundamental unit of analysis in datatable is a Frame. It is the same notion as a pandas DataFrame or SQL table: data arranged in a two-dimensional array with rows and columns.

# %%
# %%time
dt_df = dt.fread("data.csv")
# Out:
# CPU times: user 33.7 s, sys: 5.16 s, total: 38.9 s
# Wall time: 23.6 s

# %% [markdown]
# The `fread()` function shown above is both powerful and extremely fast. It can automatically detect parse parameters for the majority of text files, load data from .zip archives or URLs, read Excel files, and much more.
#
# The datatable parser
#
# * Automatically detects separators, headers, column types, quoting rules, etc.
# * Reads from file, URL, shell, raw text, archives, glob
# * Provides multi-threaded file reading for maximum speed
# * Includes a progress indicator when reading large files
# * Reads both RFC4180-compliant and non-compliant files

# %% [markdown]
# ## Reading Data with Pandas
#
# Now, let us calculate the time taken by pandas to read in the same file.

# %%
# %%time
pd_df= pd.read_csv("data.csv")
# Out:
# <string>:2: DtypeWarning: Columns (19,47,55,112,123,124,125,128,129,130,133,139,140,141) have mixed types. Specify dtype option on import or set low_memory=False.
# CPU times: user 47.5 s, sys: 12.1 s, total: 59.6 s
# Wall time: 1min 4s

# %% [markdown]
# ### Converting Frame to pandas Dataframe.
# We can also convert an existing Frame into a pandas DataFrame,

# %%
# %%time
pandas_df = dt_df.to_pandas()
# Out:
# CPU times: user 17.1 s, sys: 4 s, total: 21.1 s
# Wall time: 21.4 s

# %%
type(dt_pd)

# %% [markdown]
# This shows that reading a file as datatable frame and then converting it into a pandas dataframe consumes less time.

# %% [markdown]
# ## Basic Frame Properties
#
# Let's look at some of the basic properties of frame:

# %%
print(dt_df.shape)       # (nrows, ncols)
print(dt_df.names[:5])   # top 5 column names
print(dt_df.stypes[:5])  # column types(top 5)
# Out:
# (2260668, 145)
# ('id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv')
# (stype.bool8, stype.bool8, stype.int32, stype.int32, stype.float64)

# %%
dt_df.head(10)
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool { background: #DDDD99; }
# .datatable .obj  { background: #565656; }
# .datatable .int  { background: #5D9E5D; }
# .datatable .real { background: #4040CC; }
# .datatable .str  { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>
# <div class='datatable'>
#   <table class='frame'>
#   <thead>
#     <tr class='colnames'><td class='row_index'></td><th>id</th><th>member_id</th><th>loan_amnt</th><th>funded_amnt</th><th>funded_amnt_inv</th><th>term</th><th>int_rate</th><th>installment</th><th>grade</th><th>sub_grade</th><th class='vellipsis'>&hellip;</th><th>settlement_status</th><th>settlement_date</th><th>settlement_amount</th><th>settlement_percentage</th><th>settlement_term</th></tr>
#     <tr class='coltypes'><td class='row_index'></td><td class='bool' title='bool8'>&#x25AA;</td><td class='bool' title='bool8'>&#x25AA;</td><td class='int' title='int32'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='int' title='int32'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='real' title='float64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='str' title='str32'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='real' title='float64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='real' title='float64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='str' title='str32'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='str' title='str32'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><th class='vellipsis'>&hellip;</th><td class='str' title='str32'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='str' title='str32'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='real' title='float64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='real' title='float64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='int' title='int32'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td></tr>
#   </thead>
#   <tbody>
#     <tr><td class='row_index'>0</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td>2500</td><td>2500</td><td>2500</td><td>36 months</td><td>13.56</td><td>84.92</td><td>C</td><td>C1</td><td class=vellipsis>&hellip;</td><td></td><td></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td></tr>
#     <tr><td class='row_index'>1</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td>30000</td><td>30000</td><td>30000</td><td>60 months</td><td>18.94</td><td>777.23</td><td>D</td><td>D2</td><td class=vellipsis>&hellip;</td><td></td><td></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td></tr>
#     <tr><td class='row_index'>2</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td>5000</td><td>5000</td><td>5000</td><td>36 months</td><td>17.97</td><td>180.69</td><td>D</td><td>D1</td><td class=vellipsis>&hellip;</td><td></td><td></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td></tr>
#     <tr><td class='row_index'>3</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td>4000</td><td>4000</td><td>4000</td><td>36 months</td><td>18.94</td><td>146.51</td><td>D</td><td>D2</td><td class=vellipsis>&hellip;</td><td></td><td></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td></tr>
#     <tr><td class='row_index'>4</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td>30000</td><td>30000</td><td>30000</td><td>60 months</td><td>16.14</td><td>731.78</td><td>C</td><td>C4</td><td class=vellipsis>&hellip;</td><td></td><td></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td></tr>
#     <tr><td class='row_index'>5</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td>5550</td><td>5550</td><td>5550</td><td>36 months</td><td>15.02</td><td>192.45</td><td>C</td><td>C3</td><td class=vellipsis>&hellip;</td><td></td><td></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td></tr>
#     <tr><td class='row_index'>6</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td>2000</td><td>2000</td><td>2000</td><td>36 months</td><td>17.97</td><td>72.28</td><td>D</td><td>D1</td><td class=vellipsis>&hellip;</td><td></td><td></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td></tr>
#     <tr><td class='row_index'>7</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td>6000</td><td>6000</td><td>6000</td><td>36 months</td><td>13.56</td><td>203.79</td><td>C</td><td>C1</td><td class=vellipsis>&hellip;</td><td></td><td></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td></tr>
#     <tr><td class='row_index'>8</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td>5000</td><td>5000</td><td>5000</td><td>36 months</td><td>17.97</td><td>180.69</td><td>D</td><td>D1</td><td class=vellipsis>&hellip;</td><td></td><td></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td></tr>
#     <tr><td class='row_index'>9</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td>6000</td><td>6000</td><td>6000</td><td>36 months</td><td>14.47</td><td>206.44</td><td>C</td><td>C2</td><td class=vellipsis>&hellip;</td><td></td><td></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td></tr>
#   </tbody>
#   </table>
#   <div class='footer'>
#     <div class='frame_dimensions'>10 rows &times; 145 columns</div>
#   </div>
# </div>

# %% [markdown]
# ## Summary Stats
# Calculating the summary stats in pandas is a memory consuming process but not anymore with datatable. We can compute the following per-column summary stats using datatable:

# %% [markdown]
# ### mean of all the columns
#
# #### Using datatable

# %%
# %%time
dt_df.mean()
# Out:
# CPU times: user 5.11 s, sys: 51.8 ms, total: 5.16 s
# Wall time: 1.43 s
# <div class='datatable'>
#   <table class='frame'>
#   <thead>
#     <tr class='colnames'><td class='row_index'></td><th>id</th><th>member_id</th><th>loan_amnt</th><th>funded_amnt</th><th>funded_amnt_inv</th><th>term</th><th>int_rate</th><th>installment</th><th>grade</th><th>sub_grade</th><th class='vellipsis'>&hellip;</th><th>settlement_status</th><th>settlement_date</th><th>settlement_amount</th><th>settlement_percentage</th><th>settlement_term</th></tr>
#     <tr class='coltypes'><td class='row_index'></td><td class='real' title='float64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='real' title='float64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='real' title='float64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='real' title='float64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='real' title='float64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='real' title='float64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='real' title='float64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='real' title='float64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='real' title='float64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='real' title='float64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><th class='vellipsis'>&hellip;</th><td class='real' title='float64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='real' title='float64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='real' title='float64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='real' title='float64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='real' title='float64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td></tr>
#   </thead>
#   <tbody>
#     <tr><td class='row_index'>0</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td>15046.9</td><td>15041.7</td><td>15023.4</td><td><span class=na>NA</span></td><td>13.0929</td><td>445.808</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td class=vellipsis>&hellip;</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td>5030.61</td><td>47.7756</td><td>13.1486</td></tr>
#   </tbody>
#   </table>
#   <div class='footer'>
#     <div class='frame_dimensions'>1 row &times; 145 columns</div>
#   </div>
# </div>

# %% [markdown]
# #### Using pandas

# %%
# %%time
#pd_df.mean()
#Throws memory error

# %% [markdown]
# ### max of every column

# %%
dt_df.max()
# Out:
# <div class='datatable'>
#   <table class='frame'>
#   <thead>
#     <tr class='colnames'><td class='row_index'></td><th>id</th><th>member_id</th><th>loan_amnt</th><th>funded_amnt</th><th>funded_amnt_inv</th><th>term</th><th>int_rate</th><th>installment</th><th>grade</th><th>sub_grade</th><th class='vellipsis'>&hellip;</th><th>settlement_status</th><th>settlement_date</th><th>settlement_amount</th><th>settlement_percentage</th><th>settlement_term</th></tr>
#     <tr class='coltypes'><td class='row_index'></td><td class='bool' title='bool8'>&#x25AA;</td><td class='bool' title='bool8'>&#x25AA;</td><td class='int' title='int32'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='int' title='int32'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='real' title='float64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='str' title='str32'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='real' title='float64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='real' title='float64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='str' title='str32'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='str' title='str32'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><th class='vellipsis'>&hellip;</th><td class='str' title='str32'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='str' title='str32'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='real' title='float64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='real' title='float64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='int' title='int32'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td></tr>
#   </thead>
#   <tbody>
#     <tr><td class='row_index'>0</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td>40000</td><td>40000</td><td>40000</td><td><span class=na>NA</span></td><td>30.99</td><td>1719.83</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td class=vellipsis>&hellip;</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td>33601</td><td>521.35</td><td>181</td></tr>
#   </tbody>
#   </table>
#   <div class='footer'>
#     <div class='frame_dimensions'>1 row &times; 145 columns</div>
#   </div>
# </div>

# %% [markdown]
# ### Number of Unique values in every column

# %%
dt_df.nunique()
# Out:
# <div class='datatable'>
#   <table class='frame'>
#   <thead>
#     <tr class='colnames'><td class='row_index'></td><th>id</th><th>member_id</th><th>loan_amnt</th><th>funded_amnt</th><th>funded_amnt_inv</th><th>term</th><th>int_rate</th><th>installment</th><th>grade</th><th>sub_grade</th><th class='vellipsis'>&hellip;</th><th>settlement_status</th><th>settlement_date</th><th>settlement_amount</th><th>settlement_percentage</th><th>settlement_term</th></tr>
#     <tr class='coltypes'><td class='row_index'></td><td class='int' title='int64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='int' title='int64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='int' title='int64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='int' title='int64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='int' title='int64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='int' title='int64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='int' title='int64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='int' title='int64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='int' title='int64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='int' title='int64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><th class='vellipsis'>&hellip;</th><td class='int' title='int64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='int' title='int64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='int' title='int64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='int' title='int64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='int' title='int64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td></tr>
#   </thead>
#   <tbody>
#     <tr><td class='row_index'>0</td><td>0</td><td>0</td><td>1572</td><td>1572</td><td>10058</td><td>2</td><td>673</td><td>93296</td><td>7</td><td>35</td><td class=vellipsis>&hellip;</td><td>4</td><td>90</td><td>21519</td><td>2045</td><td>40</td></tr>
#   </tbody>
#   </table>
#   <div class='footer'>
#     <div class='frame_dimensions'>1 row &times; 145 columns</div>
#   </div>
# </div>

# %% [markdown]
# ## Data Manipulation
# Data Tables like dataframes are columnnar data structures.In datatable, the primary vehicle for all these operations is the square-bracket notation inspired by traditional matrix indexing but with more functionalities.
#
# ![](https://i.imgur.com/LMjIWLm.png)
#
# The same DT[i, j] notation is used in mathematics when indexing matrices, in C/C++, in R, in pandas, in numpy, etc

# %% [markdown]
# ## Selecting Subsets of Rows/Columns

# %%
dt_df[:,'funded_amnt'] # selecting the first column
# Out:
# <div class='datatable'>
#   <table class='frame'>
#   <thead>
#     <tr class='colnames'><td class='row_index'></td><th>funded_amnt</th></tr>
#     <tr class='coltypes'><td class='row_index'></td><td class='int' title='int32'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td></tr>
#   </thead>
#   <tbody>
#     <tr><td class='row_index'>0</td><td>2500</td></tr>
#     <tr><td class='row_index'>1</td><td>30000</td></tr>
#     <tr><td class='row_index'>2</td><td>5000</td></tr>
#     <tr><td class='row_index'>3</td><td>4000</td></tr>
#     <tr><td class='row_index'>4</td><td>30000</td></tr>
#     <tr><td class='row_index'>5</td><td>5550</td></tr>
#     <tr><td class='row_index'>6</td><td>2000</td></tr>
#     <tr><td class='row_index'>7</td><td>6000</td></tr>
#     <tr><td class='row_index'>8</td><td>5000</td></tr>
#     <tr><td class='row_index'>9</td><td>6000</td></tr>
#     <tr><td class='row_index'>&#x22EE;</td><td class='hellipsis'>&#x22EE;</td></tr>
#     <tr><td class='row_index'>2,260,663</td><td>12000</td></tr>
#     <tr><td class='row_index'>2,260,664</td><td>12000</td></tr>
#     <tr><td class='row_index'>2,260,665</td><td>10000</td></tr>
#     <tr><td class='row_index'>2,260,666</td><td>12000</td></tr>
#     <tr><td class='row_index'>2,260,667</td><td>16550</td></tr>
#   </tbody>
#   </table>
#   <div class='footer'>
#     <div class='frame_dimensions'>2,260,668 rows &times; 1 column</div>
#   </div>
# </div>

# %%
dt_df[:5,:3] #first 5 rows and first 3 columns
# Out:
# <div class='datatable'>
#   <table class='frame'>
#   <thead>
#     <tr class='colnames'><td class='row_index'></td><th>id</th><th>member_id</th><th>loan_amnt</th></tr>
#     <tr class='coltypes'><td class='row_index'></td><td class='bool' title='bool8'>&#x25AA;</td><td class='bool' title='bool8'>&#x25AA;</td><td class='int' title='int32'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td></tr>
#   </thead>
#   <tbody>
#     <tr><td class='row_index'>0</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td>2500</td></tr>
#     <tr><td class='row_index'>1</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td>30000</td></tr>
#     <tr><td class='row_index'>2</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td>5000</td></tr>
#     <tr><td class='row_index'>3</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td>4000</td></tr>
#     <tr><td class='row_index'>4</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td>30000</td></tr>
#   </tbody>
#   </table>
#   <div class='footer'>
#     <div class='frame_dimensions'>5 rows &times; 3 columns</div>
#   </div>
# </div>

# %% [markdown]
# ## Sorting the Frame
# ### with datatable

# %%
# %%time
dt_df.sort('funded_amnt_inv')
# Out:
# CPU times: user 534 ms, sys: 67.9 ms, total: 602 ms
# Wall time: 179 ms
# <div class='datatable'>
#   <table class='frame'>
#   <thead>
#     <tr class='colnames'><td class='row_index'></td><th>id</th><th>member_id</th><th>loan_amnt</th><th>funded_amnt</th><th>funded_amnt_inv</th><th>term</th><th>int_rate</th><th>installment</th><th>grade</th><th>sub_grade</th><th class='vellipsis'>&hellip;</th><th>settlement_status</th><th>settlement_date</th><th>settlement_amount</th><th>settlement_percentage</th><th>settlement_term</th></tr>
#     <tr class='coltypes'><td class='row_index'></td><td class='bool' title='bool8'>&#x25AA;</td><td class='bool' title='bool8'>&#x25AA;</td><td class='int' title='int32'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='int' title='int32'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='real' title='float64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='str' title='str32'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='real' title='float64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='real' title='float64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='str' title='str32'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='str' title='str32'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><th class='vellipsis'>&hellip;</th><td class='str' title='str32'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='str' title='str32'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='real' title='float64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='real' title='float64'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td><td class='int' title='int32'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td></tr>
#   </thead>
#   <tbody>
#     <tr><td class='row_index'>0</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td>1775</td><td>1775</td><td>0</td><td>36 months</td><td>12.72</td><td>59.57</td><td>C</td><td>C4</td><td class=vellipsis>&hellip;</td><td></td><td></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td></tr>
#     <tr><td class='row_index'>1</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td>7500</td><td>7500</td><td>0</td><td>36 months</td><td>10.01</td><td>242.04</td><td>B</td><td>B2</td><td class=vellipsis>&hellip;</td><td></td><td></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td></tr>
#     <tr><td class='row_index'>2</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td>4000</td><td>4000</td><td>0</td><td>36 months</td><td>7.68</td><td>124.76</td><td>A</td><td>A2</td><td class=vellipsis>&hellip;</td><td></td><td></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td></tr>
#     <tr><td class='row_index'>3</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td>3200</td><td>2100</td><td>0</td><td>36 months</td><td>7.68</td><td>65.5</td><td>A</td><td>A2</td><td class=vellipsis>&hellip;</td><td></td><td></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td></tr>
#     <tr><td class='row_index'>4</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td>7500</td><td>7500</td><td>0</td><td>36 months</td><td>11.59</td><td>247.65</td><td>C</td><td>C2</td><td class=vellipsis>&hellip;</td><td></td><td></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td></tr>
#     <tr><td class='row_index'>5</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td>7000</td><td>6100</td><td>0</td><td>36 months</td><td>11.28</td><td>200.52</td><td>C</td><td>C1</td><td class=vellipsis>&hellip;</td><td></td><td></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td></tr>
#     <tr><td class='row_index'>6</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td>7500</td><td>4750</td><td>0</td><td>36 months</td><td>11.28</td><td>156.14</td><td>C</td><td>C1</td><td class=vellipsis>&hellip;</td><td></td><td></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td></tr>
#     <tr><td class='row_index'>7</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td>5600</td><td>4300</td><td>0</td><td>36 months</td><td>8.32</td><td>135.39</td><td>A</td><td>A4</td><td class=vellipsis>&hellip;</td><td></td><td></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td></tr>
#     <tr><td class='row_index'>8</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td>7500</td><td>4800</td><td>0</td><td>36 months</td><td>11.59</td><td>158.5</td><td>C</td><td>C2</td><td class=vellipsis>&hellip;</td><td></td><td></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td></tr>
#     <tr><td class='row_index'>9</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td>7500</td><td>5550</td><td>0</td><td>36 months</td><td>8.32</td><td>174.74</td><td>A</td><td>A4</td><td class=vellipsis>&hellip;</td><td></td><td></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td></tr>
#     <tr><td class='row_index'>&#x22EE;</td><td class='hellipsis'>&#x22EE;</td><td class='hellipsis'>&#x22EE;</td><td class='hellipsis'>&#x22EE;</td><td class='hellipsis'>&#x22EE;</td><td class='hellipsis'>&#x22EE;</td><td class='hellipsis'>&#x22EE;</td><td class='hellipsis'>&#x22EE;</td><td class='hellipsis'>&#x22EE;</td><td class='hellipsis'>&#x22EE;</td><td class='hellipsis'>&#x22EE;</td><td class='hellipsis'>&#x22F1;</td><td class='hellipsis'>&#x22EE;</td><td class='hellipsis'>&#x22EE;</td><td class='hellipsis'>&#x22EE;</td><td class='hellipsis'>&#x22EE;</td><td class='hellipsis'>&#x22EE;</td></tr>
#     <tr><td class='row_index'>2,260,663</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td>40000</td><td>40000</td><td>40000</td><td>36 months</td><td>9.44</td><td>1280.2</td><td>B</td><td>B1</td><td class=vellipsis>&hellip;</td><td></td><td></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td></tr>
#     <tr><td class='row_index'>2,260,664</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td>40000</td><td>40000</td><td>40000</td><td>36 months</td><td>9.44</td><td>1280.2</td><td>B</td><td>B1</td><td class=vellipsis>&hellip;</td><td></td><td></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td></tr>
#     <tr><td class='row_index'>2,260,665</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td>40000</td><td>40000</td><td>40000</td><td>60 months</td><td>20</td><td>1059.76</td><td>D</td><td>D4</td><td class=vellipsis>&hellip;</td><td></td><td></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td></tr>
#     <tr><td class='row_index'>2,260,666</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td>40000</td><td>40000</td><td>40000</td><td>36 months</td><td>10.42</td><td>1298.59</td><td>B</td><td>B3</td><td class=vellipsis>&hellip;</td><td></td><td></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td></tr>
#     <tr><td class='row_index'>2,260,667</td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td>40000</td><td>40000</td><td>40000</td><td>36 months</td><td>10.91</td><td>1307.85</td><td>B</td><td>B4</td><td class=vellipsis>&hellip;</td><td></td><td></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td><td><span class=na>NA</span></td></tr>
#   </tbody>
#   </table>
#   <div class='footer'>
#     <div class='frame_dimensions'>2,260,668 rows &times; 145 columns</div>
#   </div>
# </div>

# %% [markdown]
# ### with pandas

# %%
# %%time
pd_df.sort_values(by = 'funded_amnt_inv')
# Out:
# CPU times: user 8.76 s, sys: 2.87 s, total: 11.6 s
# Wall time: 12.4 s
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 2138210 NaN        NaN       5500         5500              0.0   36 months
# 2138169 NaN        NaN       7500         7500              0.0   36 months
# 2141012 NaN        NaN       7225         5300              0.0   36 months
# 2141011 NaN        NaN       7500         7500              0.0   36 months
# 2138262 NaN        NaN       7000         7000              0.0   36 months
# 2138261 NaN        NaN       3500         3500              0.0   36 months
# 2141003 NaN        NaN       4000         4000              0.0   36 months
# 2140997 NaN        NaN       2400         2400              0.0   36 months
# 2140994 NaN        NaN       6000         6000              0.0   36 months
# 2138172 NaN        NaN       5000         5000              0.0   36 months
# 2140993 NaN        NaN       7500         7500              0.0   36 months
# 2140992 NaN        NaN       7000         7000              0.0   36 months
# 2138257 NaN        NaN       6000         4725              0.0   36 months
# 2140987 NaN        NaN       5000         5000              0.0   36 months
# 2140986 NaN        NaN       4500         4500              0.0   36 months
# 2137960 NaN        NaN       7500         4750              0.0   36 months
# 2140984 NaN        NaN      11000        11000              0.0   36 months
# 2138133 NaN        NaN       1600         1600              0.0   36 months
# 2138254 NaN        NaN       3500         3500              0.0   36 months
# 2140978 NaN        NaN      15000        15000              0.0   36 months
# 2140977 NaN        NaN       4000         4000              0.0   36 months
# 2138249 NaN        NaN       1500         1175              0.0   36 months
# 2138111 NaN        NaN       3000         3000              0.0   36 months
# 2137974 NaN        NaN       5600         4300              0.0   36 months
# 2137975 NaN        NaN       7500         4800              0.0   36 months
# 2137977 NaN        NaN       7500         5550              0.0   36 months
# 2138106 NaN        NaN       7000         7000              0.0   36 months
# 2137988 NaN        NaN       6000         5100              0.0   36 months
# 2138162 NaN        NaN       7500         7500              0.0   36 months
# 2138163 NaN        NaN       5000         5000              0.0   36 months
# ...      ..        ...        ...          ...              ...         ...
# 1605588 NaN        NaN      40000        40000          40000.0   36 months
# 370115  NaN        NaN      40000        40000          40000.0   36 months
# 370116  NaN        NaN      40000        40000          40000.0   60 months
# 53289   NaN        NaN      40000        40000          40000.0   36 months
# 182253  NaN        NaN      40000        40000          40000.0   36 months
# 489926  NaN        NaN      40000        40000          40000.0   36 months
# 489922  NaN        NaN      40000        40000          40000.0   60 months
# 826245  NaN        NaN      40000        40000          40000.0   60 months
# 248418  NaN        NaN      40000        40000          40000.0   60 months
# 489966  NaN        NaN      40000        40000          40000.0   36 months
# 2151510 NaN        NaN      40000        40000          40000.0   60 months
# 321183  NaN        NaN      40000        40000          40000.0   60 months
# 112364  NaN        NaN      40000        40000          40000.0   36 months
# 490085  NaN        NaN      40000        40000          40000.0   36 months
# 321199  NaN        NaN      40000        40000          40000.0   36 months
# 182190  NaN        NaN      40000        40000          40000.0   60 months
# 140808  NaN        NaN      40000        40000          40000.0   60 months
# 112373  NaN        NaN      40000        40000          40000.0   36 months
# 490051  NaN        NaN      40000        40000          40000.0   36 months
# 2151534 NaN        NaN      40000        40000          40000.0   60 months
# 490050  NaN        NaN      40000        40000          40000.0   36 months
# 1517303 NaN        NaN      40000        40000          40000.0   36 months
# 490004  NaN        NaN      40000        40000          40000.0   60 months
# 638339  NaN        NaN      40000        40000          40000.0   60 months
# 1517293 NaN        NaN      40000        40000          40000.0   60 months
# 489999  NaN        NaN      40000        40000          40000.0   60 months
# 826237  NaN        NaN      40000        40000          40000.0   60 months
# 489975  NaN        NaN      40000        40000          40000.0   60 months
# 638322  NaN        NaN      40000        40000          40000.0   60 months
# 2145538 NaN        NaN      40000        40000          40000.0   36 months
#
#          int_rate  installment grade sub_grade  ...  \
# 2138210      9.76       176.86     B        B2  ...
# 2138169     11.97       249.00     C        C4  ...
# 2141012     14.18       181.61     E        E1  ...
# 2141011     11.03       245.65     C        C1  ...
# 2138262      8.00       219.36     A        A3  ...
# 2138261      8.32       110.20     A        A4  ...
# 2141003     18.54       145.70     G        G4  ...
# 2140997     13.17        81.07     D        D2  ...
# 2140994     14.12       205.42     D        D5  ...
# 2138172     10.08       161.53     B        B3  ...
# 2140993     16.01       263.72     F        F1  ...
# 2140992     14.12       239.66     D        D5  ...
# 2138257     10.39       153.33     B        B4  ...
# 2140987      9.70       160.64     B        B1  ...
# 2140986     12.54       150.63     C        C5  ...
# 2137960     11.28       156.14     C        C1  ...
# 2140984     11.91       364.89     C        C3  ...
# 2138133     11.66        52.89     C        C3  ...
# 2138254      7.68       109.17     A        A2  ...
# 2140978     11.91       497.58     C        C3  ...
# 2140977     17.91       144.43     G        G2  ...
# 2138249      7.37        36.48     A        A1  ...
# 2138111      8.00        94.01     A        A3  ...
# 2137974      8.32       135.39     A        A4  ...
# 2137975     11.59       158.50     C        C2  ...
# 2137977      8.32       174.74     A        A4  ...
# 2138106      8.00       219.36     A        A3  ...
# 2137988      8.00       159.82     A        A3  ...
# 2138162     10.39       243.38     B        B4  ...
# 2138163     12.29       166.77     C        C5  ...
# ...           ...          ...   ...       ...  ...
# 1605588     22.91      1546.52     E        E1  ...
# 370115       5.31      1204.42     A        A1  ...
# 370116      18.45      1025.56     D        D2  ...
# 53289       11.80      1324.76     B        B4  ...
# 182253      11.55      1320.00     B        B4  ...
# 489926       9.44      1280.20     B        B1  ...
# 489922      12.62       902.37     C        C1  ...
# 826245      29.49      1281.64     F        F2  ...
# 248418      11.55       880.71     B        B4  ...
# 489966       7.35      1241.50     A        A4  ...
# 2151510      7.35       798.67     A        A4  ...
# 321183       9.58       841.64     B        B1  ...
# 112364       7.84      1250.51     A        A4  ...
# 490085       6.08      1218.33     A        A2  ...
# 321199       6.19      1220.33     A        A2  ...
# 182190      12.73       904.61     B        B5  ...
# 140808      11.55       880.71     B        B4  ...
# 112373       6.11      1218.88     A        A1  ...
# 490051       6.72      1229.97     A        A3  ...
# 2151534     15.05       952.65     C        C4  ...
# 490050       6.72      1229.97     A        A3  ...
# 1517303      9.44      1280.20     B        B1  ...
# 490004      12.62       902.37     C        C1  ...
# 638339      10.75       864.72     B        B4  ...
# 1517293     10.42       858.18     B        B3  ...
# 489999      14.08       932.39     C        C3  ...
# 826237      11.44       878.50     B        B4  ...
# 489975       9.93       848.51     B        B2  ...
# 638322       7.89       808.96     A        A5  ...
# 2145538      9.93      1289.38     B        B2  ...
#
#         hardship_payoff_balance_amount hardship_last_payment_amount  \
# 2138210                            NaN                          NaN
# 2138169                            NaN                          NaN
# 2141012                            NaN                          NaN
# 2141011                            NaN                          NaN
# 2138262                            NaN                          NaN
# 2138261                            NaN                          NaN
# 2141003                            NaN                          NaN
# 2140997                            NaN                          NaN
# 2140994                            NaN                          NaN
# 2138172                            NaN                          NaN
# 2140993                            NaN                          NaN
# 2140992                            NaN                          NaN
# 2138257                            NaN                          NaN
# 2140987                            NaN                          NaN
# 2140986                            NaN                          NaN
# 2137960                            NaN                          NaN
# 2140984                            NaN                          NaN
# 2138133                            NaN                          NaN
# 2138254                            NaN                          NaN
# 2140978                            NaN                          NaN
# 2140977                            NaN                          NaN
# 2138249                            NaN                          NaN
# 2138111                            NaN                          NaN
# 2137974                            NaN                          NaN
# 2137975                            NaN                          NaN
# 2137977                            NaN                          NaN
# 2138106                            NaN                          NaN
# 2137988                            NaN                          NaN
# 2138162                            NaN                          NaN
# 2138163                            NaN                          NaN
# ...                                ...                          ...
# 1605588                            NaN                          NaN
# 370115                             NaN                          NaN
# 370116                             NaN                          NaN
# 53289                              NaN                          NaN
# 182253                             NaN                          NaN
# 489926                             NaN                          NaN
# 489922                             NaN                          NaN
# 826245                             NaN                          NaN
# 248418                             NaN                          NaN
# 489966                             NaN                          NaN
# 2151510                            NaN                          NaN
# 321183                             NaN                          NaN
# 112364                             NaN                          NaN
# 490085                             NaN                          NaN
# 321199                             NaN                          NaN
# 182190                             NaN                          NaN
# 140808                             NaN                          NaN
# 112373                             NaN                          NaN
# 490051                             NaN                          NaN
# 2151534                            NaN                          NaN
# 490050                             NaN                          NaN
# 1517303                            NaN                          NaN
# 490004                             NaN                          NaN
# 638339                             NaN                          NaN
# 1517293                            NaN                          NaN
# 489999                             NaN                          NaN
# 826237                             NaN                          NaN
# 489975                             NaN                          NaN
# 638322                             NaN                          NaN
# 2145538                            NaN                          NaN
#
#         disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 2138210                Cash                     N                       NaN
# 2138169                Cash                     N                       NaN
# 2141012                Cash                     N                       NaN
# 2141011                Cash                     N                       NaN
# 2138262                Cash                     N                       NaN
# 2138261                Cash                     N                       NaN
# 2141003                Cash                     N                       NaN
# 2140997                Cash                     N                       NaN
# 2140994                Cash                     N                       NaN
# 2138172                Cash                     N                       NaN
# 2140993                Cash                     N                       NaN
# 2140992                Cash                     N                       NaN
# 2138257                Cash                     N                       NaN
# 2140987                Cash                     N                       NaN
# 2140986                Cash                     N                       NaN
# 2137960                Cash                     N                       NaN
# 2140984                Cash                     N                       NaN
# 2138133                Cash                     N                       NaN
# 2138254                Cash                     N                       NaN
# 2140978                Cash                     N                       NaN
# 2140977                Cash                     N                       NaN
# 2138249                Cash                     N                       NaN
# 2138111                Cash                     N                       NaN
# 2137974                Cash                     N                       NaN
# 2137975                Cash                     N                       NaN
# 2137977                Cash                     N                       NaN
# 2138106                Cash                     N                       NaN
# 2137988                Cash                     N                       NaN
# 2138162                Cash                     N                       NaN
# 2138163                Cash                     N                       NaN
# ...                     ...                   ...                       ...
# 1605588                Cash                     N                       NaN
# 370115                 Cash                     N                       NaN
# 370116                 Cash                     N                       NaN
# 53289                  Cash                     N                       NaN
# 182253                 Cash                     N                       NaN
# 489926                 Cash                     N                       NaN
# 489922                 Cash                     N                       NaN
# 826245                 Cash                     N                       NaN
# 248418            DirectPay                     N                       NaN
# 489966                 Cash                     N                       NaN
# 2151510                Cash                     N                       NaN
# 321183                 Cash                     N                       NaN
# 112364                 Cash                     N                       NaN
# 490085                 Cash                     N                       NaN
# 321199                 Cash                     N                       NaN
# 182190                 Cash                     N                       NaN
# 140808                 Cash                     N                       NaN
# 112373            DirectPay                     N                       NaN
# 490051                 Cash                     N                       NaN
# 2151534                Cash                     N                       NaN
# 490050                 Cash                     N                       NaN
# 1517303                Cash                     N                       NaN
# 490004                 Cash                     N                       NaN
# 638339                 Cash                     N                       NaN
# 1517293                Cash                     N                       NaN
# 489999                 Cash                     N                       NaN
# 826237                 Cash                     N                       NaN
# 489975                 Cash                     N                       NaN
# 638322                 Cash                     N                       NaN
# 2145538                Cash                     N                       NaN
#
#         settlement_status settlement_date settlement_amount  \
# 2138210               NaN             NaN               NaN
# 2138169               NaN             NaN               NaN
# 2141012               NaN             NaN               NaN
# 2141011               NaN             NaN               NaN
# 2138262               NaN             NaN               NaN
# 2138261               NaN             NaN               NaN
# 2141003               NaN             NaN               NaN
# 2140997               NaN             NaN               NaN
# 2140994               NaN             NaN               NaN
# 2138172               NaN             NaN               NaN
# 2140993               NaN             NaN               NaN
# 2140992               NaN             NaN               NaN
# 2138257               NaN             NaN               NaN
# 2140987               NaN             NaN               NaN
# 2140986               NaN             NaN               NaN
# 2137960               NaN             NaN               NaN
# 2140984               NaN             NaN               NaN
# 2138133               NaN             NaN               NaN
# 2138254               NaN             NaN               NaN
# 2140978               NaN             NaN               NaN
# 2140977               NaN             NaN               NaN
# 2138249               NaN             NaN               NaN
# 2138111               NaN             NaN               NaN
# 2137974               NaN             NaN               NaN
# 2137975               NaN             NaN               NaN
# 2137977               NaN             NaN               NaN
# 2138106               NaN             NaN               NaN
# 2137988               NaN             NaN               NaN
# 2138162               NaN             NaN               NaN
# 2138163               NaN             NaN               NaN
# ...                   ...             ...               ...
# 1605588               NaN             NaN               NaN
# 370115                NaN             NaN               NaN
# 370116                NaN             NaN               NaN
# 53289                 NaN             NaN               NaN
# 182253                NaN             NaN               NaN
# 489926                NaN             NaN               NaN
# 489922                NaN             NaN               NaN
# 826245                NaN             NaN               NaN
# 248418                NaN             NaN               NaN
# 489966                NaN             NaN               NaN
# 2151510               NaN             NaN               NaN
# 321183                NaN             NaN               NaN
# 112364                NaN             NaN               NaN
# 490085                NaN             NaN               NaN
# 321199                NaN             NaN               NaN
# 182190                NaN             NaN               NaN
# 140808                NaN             NaN               NaN
# 112373                NaN             NaN               NaN
# 490051                NaN             NaN               NaN
# 2151534               NaN             NaN               NaN
# 490050                NaN             NaN               NaN
# 1517303               NaN             NaN               NaN
# 490004                NaN             NaN               NaN
# 638339                NaN             NaN               NaN
# 1517293               NaN             NaN               NaN
# 489999                NaN             NaN               NaN
# 826237                NaN             NaN               NaN
# 489975                NaN             NaN               NaN
# 638322                NaN             NaN               NaN
# 2145538               NaN             NaN               NaN
#
#          settlement_percentage settlement_term
# 2138210                    NaN             NaN
# 2138169                    NaN             NaN
# 2141012                    NaN             NaN
# 2141011                    NaN             NaN
# 2138262                    NaN             NaN
# 2138261                    NaN             NaN
# 2141003                    NaN             NaN
# 2140997                    NaN             NaN
# 2140994                    NaN             NaN
# 2138172                    NaN             NaN
# 2140993                    NaN             NaN
# 2140992                    NaN             NaN
# 2138257                    NaN             NaN
# 2140987                    NaN             NaN
# 2140986                    NaN             NaN
# 2137960                    NaN             NaN
# 2140984                    NaN             NaN
# 2138133                    NaN             NaN
# 2138254                    NaN             NaN
# 2140978                    NaN             NaN
# 2140977                    NaN             NaN
# 2138249                    NaN             NaN
# 2138111                    NaN             NaN
# 2137974                    NaN             NaN
# 2137975                    NaN             NaN
# 2137977                    NaN             NaN
# 2138106                    NaN             NaN
# 2137988                    NaN             NaN
# 2138162                    NaN             NaN
# 2138163                    NaN             NaN
# ...                        ...             ...
# 1605588                    NaN             NaN
# 370115                     NaN             NaN
# 370116                     NaN             NaN
# 53289                      NaN             NaN
# 182253                     NaN             NaN
# 489926                     NaN             NaN
# 489922                     NaN             NaN
# 826245                     NaN             NaN
# 248418                     NaN             NaN
# 489966                     NaN             NaN
# 2151510                    NaN             NaN
# 321183                     NaN             NaN
# 112364                     NaN             NaN
# 490085                     NaN             NaN
# 321199                     NaN             NaN
# 182190                     NaN             NaN
# 140808                     NaN             NaN
# 112373                     NaN             NaN
# 490051                     NaN             NaN
# 2151534                    NaN             NaN
# 490050                     NaN             NaN
# 1517303                    NaN             NaN
# 490004                     NaN             NaN
# 638339                     NaN             NaN
# 1517293                    NaN             NaN
# 489999                     NaN             NaN
# 826237                     NaN             NaN
# 489975                     NaN             NaN
# 638322                     NaN             NaN
# 2145538                    NaN             NaN
#
# [2260668 rows x 145 columns]

# %% [markdown]
# ## Deleting Rows/Columns
#
# Here is how we can delete the column named 'member_id':

# %%
del dt_df[:, 'member_id']

# %% [markdown]
# ## Groupby
#
# Just like in pandas, datatable also has the groupby functionalities. Let's see how we can get the mean of `funded_amount` column grouped by the `grade` column.

# %%
# %%time
for i in range(100):
    dt_df[:, dt.sum(dt.f.funded_amnt), dt.by(dt.f.grade)]
# Out:
# CPU times: user 6.41 s, sys: 1.34 s, total: 7.76 s
# Wall time: 2.42 s

# %%
# %%time
for i in range(100):
    pd_df.groupby("grade")["funded_amnt"].sum()
# Out:
# CPU times: user 12.9 s, sys: 859 ms, total: 13.7 s
# Wall time: 13.9 s

# %% [markdown]
# What does **.f** stand for?
#
# f stands for `frame proxy`, and provides a simple way to refer to the Frame that we are currently operating upon. In case of our example, dt.f simply stands for dt_df.

# %% [markdown]
# ## Filtering Rows
#
# The syntax for filtering rows is pretty similar to that of GroupBy. Let us filter those rows of `loan_amnt`for which the values of `loan_amnt` are greater than `funded_amnt`.

# %%
dt_df[dt.f.loan_amnt>dt.f.funded_amnt,"loan_amnt"]
# Out:
# <div class='datatable'>
#   <table class='frame'>
#   <thead>
#     <tr class='colnames'><td class='row_index'></td><th>loan_amnt</th></tr>
#     <tr class='coltypes'><td class='row_index'></td><td class='int' title='int32'>&#x25AA;&#x25AA;&#x25AA;&#x25AA;</td></tr>
#   </thead>
#   <tbody>
#     <tr><td class='row_index'>0</td><td>18000</td></tr>
#     <tr><td class='row_index'>1</td><td>20000</td></tr>
#     <tr><td class='row_index'>2</td><td>20000</td></tr>
#     <tr><td class='row_index'>3</td><td>5000</td></tr>
#     <tr><td class='row_index'>4</td><td>2875</td></tr>
#     <tr><td class='row_index'>5</td><td>33425</td></tr>
#     <tr><td class='row_index'>6</td><td>32000</td></tr>
#     <tr><td class='row_index'>7</td><td>25000</td></tr>
#     <tr><td class='row_index'>8</td><td>27500</td></tr>
#     <tr><td class='row_index'>9</td><td>20000</td></tr>
#     <tr><td class='row_index'>&#x22EE;</td><td class='hellipsis'>&#x22EE;</td></tr>
#     <tr><td class='row_index'>2060</td><td>25000</td></tr>
#     <tr><td class='row_index'>2061</td><td>25000</td></tr>
#     <tr><td class='row_index'>2062</td><td>7200</td></tr>
#     <tr><td class='row_index'>2063</td><td>15600</td></tr>
#     <tr><td class='row_index'>2064</td><td>10500</td></tr>
#   </tbody>
#   </table>
#   <div class='footer'>
#     <div class='frame_dimensions'>2065 rows &times; 1 column</div>
#   </div>
# </div>

# %% [markdown]
# ## Saving the Frame
# It is also possible to write the Frame's content into a csv file so that it can be used in future.

# %%
dt_df.to_csv('output.csv')

# %% [markdown]
# For more data manipulation functions, refer to the documentation page.
